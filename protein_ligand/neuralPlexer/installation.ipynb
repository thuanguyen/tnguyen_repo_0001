# %% [markdown]
# # **check environemnt**

# %%
# %%bash
# conda env list
# pwd
# Out:
# # conda environments:
# #
# base                     /opt/conda
# jupyterlab               /opt/conda/envs/jupyterlab
# prolig_0001           *  /opt/conda/envs/prolig_0001
# pytorch                  /opt/conda/envs/pytorch
# tensorflow               /opt/conda/envs/tensorflow
#
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer

# %% [markdown]
# # **installation**

# %% [markdown]
# ## ***cuda***

# %%
import subprocess

# Define the command to run
command = "conda install -y nvidia::cudatoolkit"

# Execute the command
try:
    result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("Command executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)
# Out:
# Command executed successfully:
# Channels:
#  - conda-forge
#  - defaults
#  - nvidia
# Platform: linux-64
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# ## ***torch, torchvision, torchaudio***

# %%
import subprocess

# Define the command to run
command = "conda run -n prolig_0001 pip install torch==1.13.1+cu117 torchvision==0.14.1+cu117 torchaudio==0.13.1 --extra-index-url https://download.pytorch.org/whl/cu117 --no-cache-dir"

# Execute the command
try:
    result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("Command executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)
# Out:
# Command executed successfully:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 3.4 MB/s eta 0:08:49
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 7.4 MB/s eta 0:04:02
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 17.3 MB/s eta 0:01:44
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 44.1 MB/s eta 0:00:41
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 133.2 MB/s eta 0:00:14
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 160.0 MB/s eta 0:00:12
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 155.8 MB/s eta 0:00:12
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 152.9 MB/s eta 0:00:12
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/1.8 GB 157.1 MB/s eta 0:00:12
# ...

# %% [markdown]
# ## ***torch-scatter***

# %%
import subprocess

# Define the command to run
command = "conda run -n prolig_0001 pip install torch-scatter==2.1.0 -f https://data.pyg.org/whl/torch-1.13.1+cu117.html --no-cache-dir"

# Execute the command
try:
    result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("Command executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)
# Out:
# Command executed successfully:
# Looking in links: https://data.pyg.org/whl/torch-1.13.1+cu117.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/10.1 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/10.1 MB 3.0 MB/s eta 0:00:04
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.4/10.1 MB 6.2 MB/s eta 0:00:02
#      ━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/10.1 MB 14.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━ 5.4/10.1 MB 39.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸━━ 9.5/10.1 MB 54.5 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 56.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## ***pytorch3d***

# %%
import subprocess

# Define the command to run
# Use single quotes around the entire command and double quotes inside it, or vice versa.
command = 'conda run -n prolig_0001 pip install "git+https://github.com/facebookresearch/pytorch3d.git" --force-reinstall --no-deps --no-cache-dir'

# Execute the command
try:
    result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    print("Command executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)
# Out:
# Command executed successfully:
# ...
#   Cloning https://github.com/facebookresearch/pytorch3d.git to /var/tmp/pip-req-build-oyjcuxdr
#   Resolved https://github.com/facebookresearch/pytorch3d.git to commit a27755db416644273de8d70b770f1d2e68db720b
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for pytorch3d: filename=pytorch3d-0.7.6-cp39-cp39-linux_x86_64.whl size=6003209 sha256=85744eda33ca461c031aaec6a9990a286e8d3eedb456824cb47e5940844f778a
#   Stored in directory: /var/tmp/pip-ephem-wheel-cache-su5od46f/wheels/df/c3/6f/c71faf7063d5247895147049b4ced213a8957ac3b1e464728a
# Successfully built pytorch3d
# ...

# %% [markdown]
# ## ***openfold***

# %%
import subprocess
import os

# Directory where the repo is to be cloned
repo_dir = "openfold"

# Check if the directory already exists
if os.path.isdir(repo_dir):
    print(f"The directory '{repo_dir}' already exists. Removing it to proceed.")
    subprocess.run(['rm', '-rf', repo_dir], check=True)

# Define the commands to run
commands = f"""
git clone https://github.com/aqlaboratory/openfold.git &&
cd openfold &&
sed -i 's/std=c++14/std=c++17/g' setup.py &&
conda run -n prolig_0001 pip install . --no-deps --no-cache-dir
"""

# Execute the commands
try:
    result = subprocess.run(commands, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, executable="/bin/bash")
    print("Commands executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)
# Out:
# The directory 'openfold' already exists. Removing it to proceed.
# Commands executed successfully:
# Processing /home/jupyter/google_cloud/protein_ligand/neuralPlexer/openfold
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for openfold: filename=openfold-2.0.0-cp39-cp39-linux_x86_64.whl size=348254 sha256=5777869b69bfd1db3c8cbb7ac99de6c7c6e061614adfd07dcabfbce7132af211
#   Stored in directory: /var/tmp/pip-ephem-wheel-cache-fkya36md/wheels/cf/5b/44/0b7b148b4b86939940d3586ff8d388709744713019b7f1047c
# Successfully built openfold
# ...

# %% [markdown]
# # **installation other dependencies**

# %%
import subprocess

# Define the path to the environment YAML file
env_yaml_path = "/home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/NeuralPLexer.yml"

# Define the conda environment name
env_name = "prolig_0001"

# Commands to run
commands = f"""
conda run -n {env_name} conda env update --file {env_yaml_path} &&
conda run -n {env_name} conda clean -afy
"""

# Execute the commands
try:
    # Use subprocess.run() to execute the commands
    result = subprocess.run(commands, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, executable="/bin/bash")
    print("Commands executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)

# %% [markdown]
# ## **final installation of neuralplexer**

# %%
import subprocess

# Define the conda environment name
env_name = "prolig_0001"

# Commands to run
commands = f"""
conda run -n {env_name} make install
"""

# Execute the commands
try:
    # Use subprocess.run() to execute the commands
    result = subprocess.run(commands, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True, executable="/bin/bash")
    print("Commands executed successfully:")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print("An error occurred:")
    print(e.stderr)
