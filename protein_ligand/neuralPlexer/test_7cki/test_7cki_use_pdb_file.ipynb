# %% [markdown]
# # **check env**

# %%
# %%bash
# conda env list
# pwd
# Out:
# # conda environments:
# #
# base                     /opt/conda
# jupyterlab               /opt/conda/envs/jupyterlab
# prolig_0001           *  /opt/conda/envs/prolig_0001
# pytorch                  /opt/conda/envs/pytorch
# tensorflow               /opt/conda/envs/tensorflow
#
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer

# %% [markdown]
# # **introduction**
# - [neuralpolexer](https://github.com/zrqiao/NeuralPLexer/tree/main)

# %% [markdown]
# # **running**

# %% [markdown]
# ## **test - batched_structure_sampling**

# %%
import subprocess

# Define variables for paths
input_receptor_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/complex_structure_prediction/post2019_targets/7ckiA.pdb"
input_ligand_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/complex_structure_prediction/post2019_targets/7cki_9E0_A_1.sdf|/home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/complex_structure_prediction/post2019_targets/7cki_ATP_A_1.sdf"
out_path = "/home/jupyter/google_cloud/protein_ligand/neuralPlexer/test_7cki"
model_checkpoint_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/models/complex_structure_prediction.ckpt"

command = [
    "neuralplexer-inference",
    "--task=batched_structure_sampling",
    "--input-receptor", input_receptor_path,
    "--input-ligand", input_ligand_path,
    "--out-path", out_path,
    "--model-checkpoint", model_checkpoint_path,
    "--n-samples", "1",
    "--chunk-size", "1",
    "--num-steps=20",
    "--cuda",
    "--sampler=langevin_simulated_annealing"
]

# Run the command
result = subprocess.run(command, capture_output=True, text=True)

# Print the stdout and stderr of the command
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT: Could not load pretrained MHT weights, skipping
# Could not load pretrained MHT weights, skipping
#
# STDERR: Lightning automatically upgraded your loaded checkpoint from v1.7.0 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../../neuralplexermodels_downstream_datasets_predictions/models/complex_structure_prediction.ckpt`
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/models/esm2_t33_650M_UR50D.pt" to /home/jupyter/.cache/torch/hub/checkpoints/esm2_t33_650M_UR50D.pt
# Downloading: "https://dl.fbaipublicfiles.com/fair-esm/regression/esm2_t33_650M_UR50D-contact-regression.pt" to /home/jupyter/.cache/torch/hub/checkpoints/esm2_t33_650M_UR50D-contact-regression.pt
# /opt/conda/envs/prolig_0001/lib/python3.9/site-packages/pytorch_lightning/core/saving.py:251: UserWarning: Found keys that are in the model state dict but not in the checkpoint: ['atnum2vdw_uff', 'plm.embed_tokens.weight', 'plm.layers.0.self_attn.k_proj.weight', 'plm.layers.0.self_attn.k_proj.bias', 'plm.layers.0.self_attn.v_proj.weight', 'plm.layers.0.self_attn.v_proj.bias', 'plm.layers.0.self_attn.q_proj.weight', 'plm.layers.0.self_attn.q_proj.bias', 'plm.layers.0.self_attn.out_proj.weight', 'plm.layers.0.self_attn.out_proj.bias', 'plm.layers.0.self_attn.rot_emb.inv_freq', 'plm.layers.0.self_attn_layer_norm.weight', 'plm.layers.0.self_attn_layer_norm.bias', 'plm.layers.0.fc1.weight', 'plm.layers.0.fc1.bias', 'plm.layers.0.fc2.weight', 'plm.layers.0.fc2.bias', 'plm.layers.0.final_layer_norm.weight', 'plm.layers.0.final_layer_norm.bias', 'plm.layers.1.self_attn.k_proj.weight', 'plm.layers.1.self_attn.k_proj.bias', 'plm.layers.1.self_attn.v_proj.weight', 'plm.layers.1.self_attn.v_proj.bias', 'plm.layers.1.self_attn.q_proj.weight', 'plm.layers.1.self_attn.q_proj.bias', 'plm.layers.1.self_attn.out_proj.weight', 'plm.layers.1.self_attn.out_proj.bias', 'plm.layers.1.self_attn.rot_emb.inv_freq', 'plm.layers.1.self_attn_layer_norm.weight', 'plm.layers.1.self_attn_layer_norm.bias', 'plm.layers.1.fc1.weight', 'plm.layers.1.fc1.bias', 'plm.layers.1.fc2.weight', 'plm.layers.1.fc2.bias', 'plm.layers.1.final_layer_norm.weight', 'plm.layers.1.final_layer_norm.bias', 'plm.layers.2.self_attn.k_proj.weight', 'plm.layers.2.self_attn.k_proj.bias', 'plm.layers.2.self_attn.v_proj.weight', 'plm.layers.2.self_attn.v_proj.bias', 'plm.layers.2.self_attn.q_proj.weight', 'plm.layers.2.self_attn.q_proj.bias', 'plm.layers.2.self_attn.out_proj.weight', 'plm.layers.2.self_attn.out_proj.bias', 'plm.layers.2.self_attn.rot_emb.inv_freq', 'plm.layers.2.self_attn_layer_norm.weight', 'plm.layers.2.self_attn_layer_norm.bias', 'plm.layers.2.fc1.weight', 'plm.layers.2.fc1.bias', 'plm.layers.2.fc2.weight', 'plm.layers.2.fc2.bias', 'plm.layers.2.final_layer_norm.weight', 'plm.layers.2.final_layer_norm.bias', 'plm.layers.3.self_attn.k_proj.weight', 'plm.layers.3.self_attn.k_proj.bias', 'plm.layers.3.self_attn.v_proj.weight', 'plm.layers.3.self_attn.v_proj.bias', 'plm.layers.3.self_attn.q_proj.weight', 'plm.layers.3.self_attn.q_proj.bias', 'plm.layers.3.self_attn.out_proj.weight', 'plm.layers.3.self_attn.out_proj.bias', 'plm.layers.3.self_attn.rot_emb.inv_freq', 'plm.layers.3.self_attn_layer_norm.weight', 'plm.layers.3.self_attn_layer_norm.bias', 'plm.layers.3.fc1.weight', 'plm.layers.3.fc1.bias', 'plm.layers.3.fc2.weight', 'plm.layers.3.fc2.bias', 'plm.layers.3.final_layer_norm.weight', 'plm.layers.3.final_layer_norm.bias', 'plm.layers.4.self_attn.k_proj.weight', 'plm.layers.4.self_attn.k_proj.bias', 'plm.layers.4.self_attn.v_proj.weight', 'plm.layers.4.self_attn.v_proj.bias', 'plm.layers.4.self_attn.q_proj.weight', 'plm.layers.4.self_attn.q_proj.bias', 'plm.layers.4.self_attn.out_proj.weight', 'plm.layers.4.self_attn.out_proj.bias', 'plm.layers.4.self_attn.rot_emb.inv_freq', 'plm.layers.4.self_attn_layer_norm.weight', 'plm.layers.4.self_attn_layer_norm.bias', 'plm.layers.4.fc1.weight', 'plm.layers.4.fc1.bias', 'plm.layers.4.fc2.weight', 'plm.layers.4.fc2.bias', 'plm.layers.4.final_layer_norm.weight', 'plm.layers.4.final_layer_norm.bias', 'plm.layers.5.self_attn.k_proj.weight', 'plm.layers.5.self_attn.k_proj.bias', 'plm.layers.5.self_attn.v_proj.weight', 'plm.layers.5.self_attn.v_proj.bias', 'plm.layers.5.self_attn.q_proj.weight', 'plm.layers.5.self_attn.q_proj.bias', 'plm.layers.5.self_attn.out_proj.weight', 'plm.layers.5.self_attn.out_proj.bias', 'plm.layers.5.self_attn.rot_emb.inv_freq', 'plm.layers.5.self_attn_layer_norm.weight', 'plm.layers.5.self_attn_layer_norm.bias', 'plm.layers.5.fc1.weight', 'plm.layers.5.fc1.bias', 'plm.layers.5.fc2.weight', 'plm.layers.5.fc2.bias', 'plm.layers.5.final_layer_norm.weight', 'plm.layers.5.final_layer_norm.bias', 'plm.layers.6.s ...
#   rank_zero_warn(
# Lightning automatically upgraded your loaded checkpoint from v1.7.0 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../../neuralplexermodels_downstream_datasets_predictions/models/complex_structure_prediction.ckpt`
# /opt/conda/envs/prolig_0001/lib/python3.9/site-packages/pytorch_lightning/core/saving.py:251: UserWarning: Found keys that are in the model state dict but not in the checkpoint: ['atnum2vdw_uff', 'plm.embed_tokens.weight', 'plm.layers.0.self_attn.k_proj.weight', 'plm.layers.0.self_attn.k_proj.bias', 'plm.layers.0.self_attn.v_proj.weight', 'plm.layers.0.self_attn.v_proj.bias', 'plm.layers.0.self_attn.q_proj.weight', 'plm.layers.0.self_attn.q_proj.bias', 'plm.layers.0.self_attn.out_proj.weight', 'plm.layers.0.self_attn.out_proj.bias', 'plm.layers.0.self_attn.rot_emb.inv_freq', 'plm.layers.0.self_attn_layer_norm.weight', 'plm.layers.0.self_attn_layer_norm.bias', 'plm.layers.0.fc1.weight', 'plm.layers.0.fc1.bias', 'plm.layers.0.fc2.weight', 'plm.layers.0.fc2.bias', 'plm.layers.0.final_layer_norm.weight', 'plm.layers.0.final_layer_norm.bias', 'plm.layers.1.self_attn.k_proj.weight', 'plm.layers.1.self_attn.k_proj.bias', 'plm.layers.1.self_attn.v_proj.weight', 'plm.layers.1.self_attn.v_proj.bias', 'plm.layers.1.self_attn.q_proj.weight', 'plm.layers.1.self_attn.q_proj.bias', 'plm.layers.1.self_attn.out_proj.weight', 'plm.layers.1.self_attn.out_proj.bias', 'plm.layers.1.self_attn.rot_emb.inv_freq', 'plm.layers.1.self_attn_layer_norm.weight', 'plm.layers.1.self_attn_layer_norm.bias', 'plm.layers.1.fc1.weight', 'plm.layers.1.fc1.bias', 'plm.layers.1.fc2.weight', 'plm.layers.1.fc2.bias', 'plm.layers.1.final_layer_norm.weight', 'plm.layers.1.final_layer_norm.bias', 'plm.layers.2.self_attn.k_proj.weight', 'plm.layers.2.self_attn.k_proj.bias', 'plm.layers.2.self_attn.v_proj.weight', 'plm.layers.2.self_attn.v_proj.bias', 'plm.layers.2.self_attn.q_proj.weight', 'plm.layers.2.self_attn.q_proj.bias', 'plm.layers.2.self_attn.out_proj.weight', 'plm.layers.2.self_attn.out_proj.bias', 'plm.layers.2.self_attn.rot_emb.inv_freq', 'plm.layers.2.self_attn_layer_norm.weight', 'plm.layers.2.self_attn_layer_norm.bias', 'plm.layers.2.fc1.weight', 'plm.layers.2.fc1.bias', 'plm.layers.2.fc2.weight', 'plm.layers.2.fc2.bias', 'plm.layers.2.final_layer_norm.weight', 'plm.layers.2.final_layer_norm.bias', 'plm.layers.3.self_attn.k_proj.weight', 'plm.layers.3.self_attn.k_proj.bias', 'plm.layers.3.self_attn.v_proj.weight', 'plm.layers.3.self_attn.v_proj.bias', 'plm.layers.3.self_attn.q_proj.weight', 'plm.layers.3.self_attn.q_proj.bias', 'plm.layers.3.self_attn.out_proj.weight', 'plm.layers.3.self_attn.out_proj.bias', 'plm.layers.3.self_attn.rot_emb.inv_freq', 'plm.layers.3.self_attn_layer_norm.weight', 'plm.layers.3.self_attn_layer_norm.bias', 'plm.layers.3.fc1.weight', 'plm.layers.3.fc1.bias', 'plm.layers.3.fc2.weight', 'plm.layers.3.fc2.bias', 'plm.layers.3.final_layer_norm.weight', 'plm.layers.3.final_layer_norm.bias', 'plm.layers.4.self_attn.k_proj.weight', 'plm.layers.4.self_attn.k_proj.bias', 'plm.layers.4.self_attn.v_proj.weight', 'plm.layers.4.self_attn.v_proj.bias', 'plm.layers.4.self_attn.q_proj.weight', 'plm.layers.4.self_attn.q_proj.bias', 'plm.layers.4.self_attn.out_proj.weight', 'plm.layers.4.self_attn.out_proj.bias', 'plm.layers.4.self_attn.rot_emb.inv_freq', 'plm.layers.4.self_attn_layer_norm.weight', 'plm.layers.4.self_attn_layer_norm.bias', 'plm.layers.4.fc1.weight', 'plm.layers.4.fc1.bias', 'plm.layers.4.fc2.weight', 'plm.layers.4.fc2.bias', 'plm.layers.4.final_layer_norm.weight', 'plm.layers.4.final_layer_norm.bias', 'plm.layers.5.self_attn.k_proj.weight', 'plm.layers.5.self_attn.k_proj.bias', 'plm.layers.5.self_attn.v_proj.weight', 'plm.layers.5.self_attn.v_proj.bias', 'plm.layers.5.self_attn.q_proj.weight', 'plm.layers.5.self_attn.q_proj.bias', 'plm.layers.5.self_attn.out_proj.weight', 'plm.layers.5.self_attn.out_proj.bias', 'plm.layers.5.self_attn.rot_emb.inv_freq', 'plm.layers.5.self_attn_layer_norm.weight', 'plm.layers.5.self_attn_layer_norm.bias', 'plm.layers.5.fc1.weight', 'plm.layers.5.fc1.bias', 'plm.layers.5.fc2.weight', 'plm.layers.5.fc2.bias', 'plm.layers.5.final_layer_norm.weight', 'plm.layers.5.final_layer_norm.bias', 'plm.layers.6.s ...
#   rank_zero_warn(
#
# Block contact sampling:   0%|          | 0/31 [00:00<?, ?it/s]
# Block contact sampling:  10%|▉         | 3/31 [00:00<00:01, 24.91it/s]
# Block contact sampling:  19%|█▉        | 6/31 [00:00<00:01, 24.49it/s]
# Block contact sampling:  29%|██▉       | 9/31 [00:00<00:00, 24.13it/s]
# Block contact sampling:  39%|███▊      | 12/31 [00:00<00:00, 24.17it/s]
# Block contact sampling:  48%|████▊     | 15/31 [00:00<00:00, 24.16it/s]
# Block contact sampling:  58%|█████▊    | 18/31 [00:00<00:00, 24.20it/s]
# Block contact sampling:  68%|██████▊   | 21/31 [00:00<00:00, 24.07it/s]
# Block contact sampling:  77%|███████▋  | 24/31 [00:00<00:00, 23.93it/s]
# Block contact sampling:  87%|████████▋ | 27/31 [00:01<00:00, 24.04it/s]
# Block contact sampling:  97%|█████████▋| 30/31 [00:01<00:00, 24.12it/s]
# Block contact sampling: 100%|██████████| 31/31 [00:01<00:00, 24.15it/s]
#
# Structure generation using langevin_simulated_annealing:   0%|          | 0/20 [00:00<?, ?it/s]
# Structure generation using langevin_simulated_annealing:   5%|▌         | 1/20 [00:00<00:02,  7.44it/s]
# Structure generation using langevin_simulated_annealing:  10%|█         | 2/20 [00:02<00:23,  1.33s/it]
# Structure generation using langevin_simulated_annealing:  15%|█▌        | 3/20 [00:02<00:13,  1.29it/s]
# Structure generation using langevin_simulated_annealing:  20%|██        | 4/20 [00:02<00:08,  1.93it/s]
# Structure generation using langevin_simulated_annealing:  25%|██▌       | 5/20 [00:02<00:05,  2.67it/s]
# Structure generation using langevin_simulated_annealing:  30%|███       | 6/20 [00:02<00:04,  3.48it/s]
# Structure generation using langevin_simulated_annealing:  35%|███▌      | 7/20 [00:02<00:03,  4.31it/s]
# Structure generation using langevin_simulated_annealing:  40%|████      | 8/20 [00:03<00:02,  5.12it/s]
# Structure generation using langevin_simulated_annealing:  45%|████▌     | 9/20 [00:03<00:01,  5.85it/s]
# Structure generation using langevin_simulated_annealing:  50%|█████     | 10/20 [00:03<00:01,  6.51it/s]
# Structure generation using langevin_simulated_annealing:  55%|█████▌    | 11/20 [00:03<00:01,  7.04it/s]
# Structure generation using langevin_simulated_annealing:  60%|██████    | 12/20 [00:03<00:01,  7.44it/s]
# Structure generation using langevin_simulated_annealing:  65%|██████▌   | 13/20 [00:03<00:00,  7.74it/s]
# Structure generation using langevin_simulated_annealing:  70%|███████   | 14/20 [00:03<00:00,  7.99it/s]
# Structure generation using langevin_simulated_annealing:  75%|███████▌  | 15/20 [00:03<00:00,  8.18it/s]
# Structure generation using langevin_simulated_annealing:  80%|████████  | 16/20 [00:03<00:00,  8.32it/s]
# Structure generation using langevin_simulated_annealing:  85%|████████▌ | 17/20 [00:04<00:00,  8.39it/s]
# Structure generation using langevin_simulated_annealing:  90%|█████████ | 18/20 [00:04<00:00,  8.44it/s]
# Structure generation using langevin_simulated_annealing:  95%|█████████▌| 19/20 [00:04<00:00,  8.48it/s]
# Structure generation using langevin_simulated_annealing: 100%|██████████| 20/20 [00:04<00:00,  8.53it/s]
# Structure generation using langevin_simulated_annealing: 100%|██████████| 20/20 [00:04<00:00,  4.54it/s]

# %% [markdown]
# ## **test - binding_site_recovery_benchmarking**

# %%
import subprocess

# Define variables for paths
input_receptor_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery"
input_ligand_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery"
csv_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/test_index.csv"  # Add the correct path to your CSV file here
out_path = "/home/jupyter/google_cloud/protein_ligand/neuralPlexer/test_7cki"
model_checkpoint_path = "/home/jupyter/neuralplexermodels_downstream_datasets_predictions/models/pdbbind_finetuned/structure_recovery_inpainting.ckpt"

command = [
    "neuralplexer-inference",
    "--task=binding_site_recovery_benchmarking",
    "--input-receptor", input_receptor_path,
    "--input-ligand", input_ligand_path,
    "--csv-path", csv_path,  # Add this line to include the CSV path in the command
    "--out-path", out_path,
    "--model-checkpoint", model_checkpoint_path,
    "--n-samples", "1",
    "--chunk-size", "1",
    "--num-steps=20",
    "--cuda",
    "--sampler=langevin_simulated_annealing"
]

# Run the command
result = subprocess.run(command, capture_output=True, text=True)

# Print the stdout and stderr of the command
print("STDOUT:", result.stdout)
print("STDERR:", result.stderr)
# Out:
# STDOUT:
# STDERR: Lightning automatically upgraded your loaded checkpoint from v1.7.0 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../../../neuralplexermodels_downstream_datasets_predictions/models/pdbbind_finetuned/structure_recovery_inpainting.ckpt`
# /opt/conda/envs/prolig_0001/lib/python3.9/site-packages/pytorch_lightning/core/saving.py:251: UserWarning: Found keys that are in the model state dict but not in the checkpoint: ['plm.embed_tokens.weight', 'plm.layers.0.self_attn.k_proj.weight', 'plm.layers.0.self_attn.k_proj.bias', 'plm.layers.0.self_attn.v_proj.weight', 'plm.layers.0.self_attn.v_proj.bias', 'plm.layers.0.self_attn.q_proj.weight', 'plm.layers.0.self_attn.q_proj.bias', 'plm.layers.0.self_attn.out_proj.weight', 'plm.layers.0.self_attn.out_proj.bias', 'plm.layers.0.self_attn.rot_emb.inv_freq', 'plm.layers.0.self_attn_layer_norm.weight', 'plm.layers.0.self_attn_layer_norm.bias', 'plm.layers.0.fc1.weight', 'plm.layers.0.fc1.bias', 'plm.layers.0.fc2.weight', 'plm.layers.0.fc2.bias', 'plm.layers.0.final_layer_norm.weight', 'plm.layers.0.final_layer_norm.bias', 'plm.layers.1.self_attn.k_proj.weight', 'plm.layers.1.self_attn.k_proj.bias', 'plm.layers.1.self_attn.v_proj.weight', 'plm.layers.1.self_attn.v_proj.bias', 'plm.layers.1.self_attn.q_proj.weight', 'plm.layers.1.self_attn.q_proj.bias', 'plm.layers.1.self_attn.out_proj.weight', 'plm.layers.1.self_attn.out_proj.bias', 'plm.layers.1.self_attn.rot_emb.inv_freq', 'plm.layers.1.self_attn_layer_norm.weight', 'plm.layers.1.self_attn_layer_norm.bias', 'plm.layers.1.fc1.weight', 'plm.layers.1.fc1.bias', 'plm.layers.1.fc2.weight', 'plm.layers.1.fc2.bias', 'plm.layers.1.final_layer_norm.weight', 'plm.layers.1.final_layer_norm.bias', 'plm.layers.2.self_attn.k_proj.weight', 'plm.layers.2.self_attn.k_proj.bias', 'plm.layers.2.self_attn.v_proj.weight', 'plm.layers.2.self_attn.v_proj.bias', 'plm.layers.2.self_attn.q_proj.weight', 'plm.layers.2.self_attn.q_proj.bias', 'plm.layers.2.self_attn.out_proj.weight', 'plm.layers.2.self_attn.out_proj.bias', 'plm.layers.2.self_attn.rot_emb.inv_freq', 'plm.layers.2.self_attn_layer_norm.weight', 'plm.layers.2.self_attn_layer_norm.bias', 'plm.layers.2.fc1.weight', 'plm.layers.2.fc1.bias', 'plm.layers.2.fc2.weight', 'plm.layers.2.fc2.bias', 'plm.layers.2.final_layer_norm.weight', 'plm.layers.2.final_layer_norm.bias', 'plm.layers.3.self_attn.k_proj.weight', 'plm.layers.3.self_attn.k_proj.bias', 'plm.layers.3.self_attn.v_proj.weight', 'plm.layers.3.self_attn.v_proj.bias', 'plm.layers.3.self_attn.q_proj.weight', 'plm.layers.3.self_attn.q_proj.bias', 'plm.layers.3.self_attn.out_proj.weight', 'plm.layers.3.self_attn.out_proj.bias', 'plm.layers.3.self_attn.rot_emb.inv_freq', 'plm.layers.3.self_attn_layer_norm.weight', 'plm.layers.3.self_attn_layer_norm.bias', 'plm.layers.3.fc1.weight', 'plm.layers.3.fc1.bias', 'plm.layers.3.fc2.weight', 'plm.layers.3.fc2.bias', 'plm.layers.3.final_layer_norm.weight', 'plm.layers.3.final_layer_norm.bias', 'plm.layers.4.self_attn.k_proj.weight', 'plm.layers.4.self_attn.k_proj.bias', 'plm.layers.4.self_attn.v_proj.weight', 'plm.layers.4.self_attn.v_proj.bias', 'plm.layers.4.self_attn.q_proj.weight', 'plm.layers.4.self_attn.q_proj.bias', 'plm.layers.4.self_attn.out_proj.weight', 'plm.layers.4.self_attn.out_proj.bias', 'plm.layers.4.self_attn.rot_emb.inv_freq', 'plm.layers.4.self_attn_layer_norm.weight', 'plm.layers.4.self_attn_layer_norm.bias', 'plm.layers.4.fc1.weight', 'plm.layers.4.fc1.bias', 'plm.layers.4.fc2.weight', 'plm.layers.4.fc2.bias', 'plm.layers.4.final_layer_norm.weight', 'plm.layers.4.final_layer_norm.bias', 'plm.layers.5.self_attn.k_proj.weight', 'plm.layers.5.self_attn.k_proj.bias', 'plm.layers.5.self_attn.v_proj.weight', 'plm.layers.5.self_attn.v_proj.bias', 'plm.layers.5.self_attn.q_proj.weight', 'plm.layers.5.self_attn.q_proj.bias', 'plm.layers.5.self_attn.out_proj.weight', 'plm.layers.5.self_attn.out_proj.bias', 'plm.layers.5.self_attn.rot_emb.inv_freq', 'plm.layers.5.self_attn_layer_norm.weight', 'plm.layers.5.self_attn_layer_norm.bias', 'plm.layers.5.fc1.weight', 'plm.layers.5.fc1.bias', 'plm.layers.5.fc2.weight', 'plm.layers.5.fc2.bias', 'plm.layers.5.final_layer_norm.weight', 'plm.layers.5.final_layer_norm.bias', 'plm.layers.6.self_attn.k_proj.w ...
#   rank_zero_warn(
# Lightning automatically upgraded your loaded checkpoint from v1.7.0 to v1.9.5. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint --file ../../../../neuralplexermodels_downstream_datasets_predictions/models/pdbbind_finetuned/structure_recovery_inpainting.ckpt`
# /opt/conda/envs/prolig_0001/lib/python3.9/site-packages/pytorch_lightning/core/saving.py:251: UserWarning: Found keys that are in the model state dict but not in the checkpoint: ['plm.embed_tokens.weight', 'plm.layers.0.self_attn.k_proj.weight', 'plm.layers.0.self_attn.k_proj.bias', 'plm.layers.0.self_attn.v_proj.weight', 'plm.layers.0.self_attn.v_proj.bias', 'plm.layers.0.self_attn.q_proj.weight', 'plm.layers.0.self_attn.q_proj.bias', 'plm.layers.0.self_attn.out_proj.weight', 'plm.layers.0.self_attn.out_proj.bias', 'plm.layers.0.self_attn.rot_emb.inv_freq', 'plm.layers.0.self_attn_layer_norm.weight', 'plm.layers.0.self_attn_layer_norm.bias', 'plm.layers.0.fc1.weight', 'plm.layers.0.fc1.bias', 'plm.layers.0.fc2.weight', 'plm.layers.0.fc2.bias', 'plm.layers.0.final_layer_norm.weight', 'plm.layers.0.final_layer_norm.bias', 'plm.layers.1.self_attn.k_proj.weight', 'plm.layers.1.self_attn.k_proj.bias', 'plm.layers.1.self_attn.v_proj.weight', 'plm.layers.1.self_attn.v_proj.bias', 'plm.layers.1.self_attn.q_proj.weight', 'plm.layers.1.self_attn.q_proj.bias', 'plm.layers.1.self_attn.out_proj.weight', 'plm.layers.1.self_attn.out_proj.bias', 'plm.layers.1.self_attn.rot_emb.inv_freq', 'plm.layers.1.self_attn_layer_norm.weight', 'plm.layers.1.self_attn_layer_norm.bias', 'plm.layers.1.fc1.weight', 'plm.layers.1.fc1.bias', 'plm.layers.1.fc2.weight', 'plm.layers.1.fc2.bias', 'plm.layers.1.final_layer_norm.weight', 'plm.layers.1.final_layer_norm.bias', 'plm.layers.2.self_attn.k_proj.weight', 'plm.layers.2.self_attn.k_proj.bias', 'plm.layers.2.self_attn.v_proj.weight', 'plm.layers.2.self_attn.v_proj.bias', 'plm.layers.2.self_attn.q_proj.weight', 'plm.layers.2.self_attn.q_proj.bias', 'plm.layers.2.self_attn.out_proj.weight', 'plm.layers.2.self_attn.out_proj.bias', 'plm.layers.2.self_attn.rot_emb.inv_freq', 'plm.layers.2.self_attn_layer_norm.weight', 'plm.layers.2.self_attn_layer_norm.bias', 'plm.layers.2.fc1.weight', 'plm.layers.2.fc1.bias', 'plm.layers.2.fc2.weight', 'plm.layers.2.fc2.bias', 'plm.layers.2.final_layer_norm.weight', 'plm.layers.2.final_layer_norm.bias', 'plm.layers.3.self_attn.k_proj.weight', 'plm.layers.3.self_attn.k_proj.bias', 'plm.layers.3.self_attn.v_proj.weight', 'plm.layers.3.self_attn.v_proj.bias', 'plm.layers.3.self_attn.q_proj.weight', 'plm.layers.3.self_attn.q_proj.bias', 'plm.layers.3.self_attn.out_proj.weight', 'plm.layers.3.self_attn.out_proj.bias', 'plm.layers.3.self_attn.rot_emb.inv_freq', 'plm.layers.3.self_attn_layer_norm.weight', 'plm.layers.3.self_attn_layer_norm.bias', 'plm.layers.3.fc1.weight', 'plm.layers.3.fc1.bias', 'plm.layers.3.fc2.weight', 'plm.layers.3.fc2.bias', 'plm.layers.3.final_layer_norm.weight', 'plm.layers.3.final_layer_norm.bias', 'plm.layers.4.self_attn.k_proj.weight', 'plm.layers.4.self_attn.k_proj.bias', 'plm.layers.4.self_attn.v_proj.weight', 'plm.layers.4.self_attn.v_proj.bias', 'plm.layers.4.self_attn.q_proj.weight', 'plm.layers.4.self_attn.q_proj.bias', 'plm.layers.4.self_attn.out_proj.weight', 'plm.layers.4.self_attn.out_proj.bias', 'plm.layers.4.self_attn.rot_emb.inv_freq', 'plm.layers.4.self_attn_layer_norm.weight', 'plm.layers.4.self_attn_layer_norm.bias', 'plm.layers.4.fc1.weight', 'plm.layers.4.fc1.bias', 'plm.layers.4.fc2.weight', 'plm.layers.4.fc2.bias', 'plm.layers.4.final_layer_norm.weight', 'plm.layers.4.final_layer_norm.bias', 'plm.layers.5.self_attn.k_proj.weight', 'plm.layers.5.self_attn.k_proj.bias', 'plm.layers.5.self_attn.v_proj.weight', 'plm.layers.5.self_attn.v_proj.bias', 'plm.layers.5.self_attn.q_proj.weight', 'plm.layers.5.self_attn.q_proj.bias', 'plm.layers.5.self_attn.out_proj.weight', 'plm.layers.5.self_attn.out_proj.bias', 'plm.layers.5.self_attn.rot_emb.inv_freq', 'plm.layers.5.self_attn_layer_norm.weight', 'plm.layers.5.self_attn_layer_norm.bias', 'plm.layers.5.fc1.weight', 'plm.layers.5.fc1.bias', 'plm.layers.5.fc2.weight', 'plm.layers.5.fc2.bias', 'plm.layers.5.final_layer_norm.weight', 'plm.layers.5.final_layer_norm.bias', 'plm.layers.6.self_attn.k_proj.w ...
#   rank_zero_warn(
#
#   0%|          | 0/143 [00:00<?, ?it/s][04:32:34] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6NP2A failed: [Errno 2] No such file or directory: 'None/6NP2A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:34] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6UVPA failed: [Errno 2] No such file or directory: 'None/6UVPA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#   1%|▏         | 2/143 [00:00<00:10, 13.40it/s][04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6JSNA failed: [Errno 2] No such file or directory: 'None/6JSNA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OIOA failed: [Errno 2] No such file or directory: 'None/6OIOA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#   3%|▎         | 4/143 [00:00<00:11, 12.46it/s][04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6E4CA failed: [Errno 2] No such file or directory: 'None/6E4CA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G24A failed: [Errno 2] No such file or directory: 'None/6G24A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#   4%|▍         | 6/143 [00:00<00:09, 14.51it/s][04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6SEOA failed: [Errno 2] No such file or directory: 'None/6SEOA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:35] Can't kekulize mol.  Unkekulized atoms: 12 13 14 15 16 17 18 20 21
# [04:32:35] ERROR: Could not sanitize molecule ending on line 87
# [04:32:35] ERROR: Can't kekulize mol.  Unkekulized atoms: 12 13 14 15 16 17 18 20 21
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6DYZA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6DYZA failed: [Errno 2] No such file or directory: 'None/6DYZA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#   6%|▌         | 8/143 [00:00<00:14,  9.26it/s][04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 5ZE6A failed: [Errno 2] No such file or directory: 'None/5ZE6A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6A6KA failed: [Errno 2] No such file or directory: 'None/6A6KA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#   7%|▋         | 10/143 [00:00<00:12, 10.95it/s][04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6E3ZA failed: [Errno 2] No such file or directory: 'None/6E3ZA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6TE6A failed: [Errno 2] No such file or directory: 'None/6TE6A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#   8%|▊         | 12/143 [00:01<00:11, 11.06it/s][04:32:35] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G2OA failed: [Errno 2] No such file or directory: 'None/6G2OA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6JSFA failed: [Errno 2] No such file or directory: 'None/6JSFA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  10%|▉         | 14/143 [00:01<00:11, 10.84it/s][04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 5ZXKA failed: [Errno 2] No such file or directory: 'None/5ZXKA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6JT3A failed: [Errno 2] No such file or directory: 'None/6JT3A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  11%|█         | 16/143 [00:01<00:10, 12.16it/s][04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QTRA failed: [Errno 2] No such file or directory: 'None/6QTRA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QZHA failed: [Errno 2] No such file or directory: 'None/6QZHA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  13%|█▎        | 18/143 [00:01<00:12,  9.84it/s][04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QMTA failed: [Errno 2] No such file or directory: 'None/6QMTA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6IBXA failed: [Errno 2] No such file or directory: 'None/6IBXA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  14%|█▍        | 20/143 [00:01<00:12, 10.17it/s][04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6CJSA failed: [Errno 2] No such file or directory: 'None/6CJSA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6N9LA failed: [Errno 2] No such file or directory: 'None/6N9LA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  15%|█▌        | 22/143 [00:02<00:11, 10.23it/s][04:32:36] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6IBZA failed: [Errno 2] No such file or directory: 'None/6IBZA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OTTA failed: [Errno 2] No such file or directory: 'None/6OTTA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  17%|█▋        | 24/143 [00:02<00:12,  9.69it/s][04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:37] Can't kekulize mol.  Unkekulized atoms: 17 18 19 20 21
# [04:32:37] ERROR: Could not sanitize molecule ending on line 67
# [04:32:37] ERROR: Can't kekulize mol.  Unkekulized atoms: 17 18 19 20 21
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6E3PA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6E3PA failed: [Errno 2] No such file or directory: 'None/6E3PA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6FE5A failed: [Errno 2] No such file or directory: 'None/6FE5A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6UWPA failed: [Errno 2] No such file or directory: 'None/6UWPA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  19%|█▉        | 27/143 [00:02<00:09, 11.87it/s][04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G2FA failed: [Errno 2] No such file or directory: 'None/6G2FA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6N53A failed: [Errno 2] No such file or directory: 'None/6N53A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  20%|██        | 29/143 [00:02<00:09, 12.40it/s][04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G2CA failed: [Errno 2] No such file or directory: 'None/6G2CA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6N0MA failed: [Errno 2] No such file or directory: 'None/6N0MA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6UVYA failed: [Errno 2] No such file or directory: 'None/6UVYA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  22%|██▏       | 32/143 [00:02<00:07, 14.62it/s][04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:37] Can't kekulize mol.  Unkekulized atoms: 0 5 6 7 9 10 13 18 19
# [04:32:37] ERROR: Could not sanitize molecule ending on line 85
# [04:32:37] ERROR: Can't kekulize mol.  Unkekulized atoms: 0 5 6 7 9 10 13 18 19
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6V5LA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6V5LA failed: [Errno 2] No such file or directory: 'None/6V5LA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:37] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 12 13 14
# [04:32:37] ERROR: Could not sanitize molecule ending on line 137
# [04:32:37] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 12 13 14
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6DZ2A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6DZ2A failed: [Errno 2] No such file or directory: 'None/6DZ2A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  24%|██▍       | 34/143 [00:02<00:07, 14.32it/s][04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MJQC failed: [Errno 2] No such file or directory: 'None/6MJQC/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6KQIA failed: [Errno 2] No such file or directory: 'None/6KQIA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  25%|██▌       | 36/143 [00:03<00:07, 13.53it/s][04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6UEGA failed: [Errno 2] No such file or directory: 'None/6UEGA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:37] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QMRA failed: [Errno 2] No such file or directory: 'None/6QMRA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  27%|██▋       | 38/143 [00:03<00:07, 14.53it/s][04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G27A failed: [Errno 2] No such file or directory: 'None/6G27A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G3CA failed: [Errno 2] No such file or directory: 'None/6G3CA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  28%|██▊       | 40/143 [00:03<00:07, 14.54it/s][04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6FCJA failed: [Errno 2] No such file or directory: 'None/6FCJA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QUVA failed: [Errno 2] No such file or directory: 'None/6QUVA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  29%|██▉       | 42/143 [00:03<00:07, 14.31it/s][04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:38] Can't kekulize mol.  Unkekulized atoms: 0 10 11 12 13 14 15 18 19
# [04:32:38] ERROR: Could not sanitize molecule ending on line 92
# [04:32:38] ERROR: Can't kekulize mol.  Unkekulized atoms: 0 10 11 12 13 14 15 18 19
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6IQLA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6IQLA failed: [Errno 2] No such file or directory: 'None/6IQLA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6RNUA failed: [Errno 2] No such file or directory: 'None/6RNUA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  31%|███       | 44/143 [00:03<00:06, 15.08it/s][04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QTOA failed: [Errno 2] No such file or directory: 'None/6QTOA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:38] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 12 13 14
# [04:32:38] ERROR: Could not sanitize molecule ending on line 134
# [04:32:38] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 12 13 14
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6DZ3A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6DZ3A failed: [Errno 2] No such file or directory: 'None/6DZ3A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  32%|███▏      | 46/143 [00:03<00:07, 12.66it/s][04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6CYHA failed: [Errno 2] No such file or directory: 'None/6CYHA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 5ZLFA failed: [Errno 2] No such file or directory: 'None/5ZLFA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  34%|███▎      | 48/143 [00:03<00:07, 12.28it/s][04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OM4A failed: [Errno 2] No such file or directory: 'None/6OM4A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:38] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6PGPA failed: [Errno 2] No such file or directory: 'None/6PGPA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  35%|███▍      | 50/143 [00:04<00:09, 10.06it/s][04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QTQA failed: [Errno 2] No such file or directory: 'None/6QTQA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:39] Can't kekulize mol.  Unkekulized atoms: 4 5 9 10 11 12 13 14 19
# [04:32:39] ERROR: Could not sanitize molecule ending on line 94
# [04:32:39] ERROR: Can't kekulize mol.  Unkekulized atoms: 4 5 9 10 11 12 13 14 19
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6GJ6A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6GJ6A failed: [Errno 2] No such file or directory: 'None/6GJ6A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  36%|███▋      | 52/143 [00:04<00:08, 10.37it/s][04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:39] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# [04:32:39] ERROR: Could not sanitize molecule ending on line 60
# [04:32:39] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6OS5A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OS5A failed: [Errno 2] No such file or directory: 'None/6OS5A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MJJC failed: [Errno 2] No such file or directory: 'None/6MJJC/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  38%|███▊      | 54/143 [00:04<00:07, 11.26it/s][04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6PZ4A failed: [Errno 2] No such file or directory: 'None/6PZ4A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6JSGA failed: [Errno 2] No such file or directory: 'None/6JSGA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  39%|███▉      | 56/143 [00:04<00:07, 11.46it/s][04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MO0A failed: [Errno 2] No such file or directory: 'None/6MO0A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6CJRA failed: [Errno 2] No such file or directory: 'None/6CJRA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  41%|████      | 58/143 [00:04<00:07, 11.18it/s][04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6TENA failed: [Errno 2] No such file or directory: 'None/6TENA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:39] Can't kekulize mol.  Unkekulized atoms: 103 104 105 106 107 108 109 110 111
# [04:32:39] ERROR: Could not sanitize molecule ending on line 554
# [04:32:39] ERROR: Can't kekulize mol.  Unkekulized atoms: 103 104 105 106 107 108 109 110 111
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6SENA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:39] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6SENA failed: [Errno 2] No such file or directory: 'None/6SENA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  42%|████▏     | 60/143 [00:05<00:10,  8.02it/s][04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G2BA failed: [Errno 2] No such file or directory: 'None/6G2BA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 5ZR3A failed: [Errno 2] No such file or directory: 'None/5ZR3A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  43%|████▎     | 62/143 [00:05<00:09,  8.89it/s][04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6E6VA failed: [Errno 2] No such file or directory: 'None/6E6VA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6PNNA failed: [Errno 2] No such file or directory: 'None/6PNNA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6NRIA failed: [Errno 2] No such file or directory: 'None/6NRIA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  45%|████▌     | 65/143 [00:05<00:07, 10.87it/s][04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6UWVA failed: [Errno 2] No such file or directory: 'None/6UWVA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OIPA failed: [Errno 2] No such file or directory: 'None/6OIPA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  47%|████▋     | 67/143 [00:05<00:06, 11.27it/s][04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MIVC failed: [Errno 2] No such file or directory: 'None/6MIVC/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6P8XA failed: [Errno 2] No such file or directory: 'None/6P8XA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  48%|████▊     | 69/143 [00:06<00:06, 10.82it/s][04:32:40] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QTSA failed: [Errno 2] No such file or directory: 'None/6QTSA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6PNMA failed: [Errno 2] No such file or directory: 'None/6PNMA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  50%|████▉     | 71/143 [00:06<00:06, 11.07it/s][04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OI8A failed: [Errno 2] No such file or directory: 'None/6OI8A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MHDA failed: [Errno 2] No such file or directory: 'None/6MHDA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  51%|█████     | 73/143 [00:06<00:06, 11.20it/s][04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6HHRA failed: [Errno 2] No such file or directory: 'None/6HHRA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6P8ZA failed: [Errno 2] No such file or directory: 'None/6P8ZA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  52%|█████▏    | 75/143 [00:06<00:06, 10.99it/s][04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6C85A failed: [Errno 2] No such file or directory: 'None/6C85A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6J06A failed: [Errno 2] No such file or directory: 'None/6J06A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6QSZA failed: [Errno 2] No such file or directory: 'None/6QSZA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  55%|█████▍    | 78/143 [00:06<00:05, 11.92it/s][04:32:41] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:41] Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17 18 19 20 22
# [04:32:41] ERROR: Could not sanitize molecule ending on line 593
# [04:32:41] ERROR: Can't kekulize mol.  Unkekulized atoms: 13 14 15 16 17 18 19 20 22
# ...
# [04:32:45] Can't kekulize mol.  Unkekulized atoms: 21 22 23 24 25 26 27 28 29
# [04:32:45] ERROR: Could not sanitize molecule ending on line 115
# [04:32:45] ERROR: Can't kekulize mol.  Unkekulized atoms: 21 22 23 24 25 26 27 28 29
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6NRJA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:45] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6NRJA failed: [Errno 2] No such file or directory: 'None/6NRJA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  86%|████████▌ | 123/143 [00:11<00:01, 11.50it/s][04:32:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6E4VA failed: [Errno 2] No such file or directory: 'None/6E4VA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OIMA failed: [Errno 2] No such file or directory: 'None/6OIMA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  87%|████████▋ | 125/143 [00:11<00:02,  6.72it/s][04:32:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6CJPA failed: [Errno 2] No such file or directory: 'None/6CJPA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  88%|████████▊ | 126/143 [00:11<00:02,  6.59it/s][04:32:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6PYBA failed: [Errno 2] No such file or directory: 'None/6PYBA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  89%|████████▉ | 127/143 [00:12<00:02,  6.84it/s][04:32:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MHCA failed: [Errno 2] No such file or directory: 'None/6MHCA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:46] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6J9WA failed: [Errno 2] No such file or directory: 'None/6J9WA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  90%|█████████ | 129/143 [00:12<00:01,  8.34it/s][04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:47] Can't kekulize mol.  Unkekulized atoms: 2 3 5 19 20 21 22 23 25
# [04:32:47] ERROR: Could not sanitize molecule ending on line 105
# [04:32:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 2 3 5 19 20 21 22 23 25
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6JUTA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6JUTA failed: [Errno 2] No such file or directory: 'None/6JUTA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  91%|█████████ | 130/143 [00:12<00:01,  8.22it/s][04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6G2EA failed: [Errno 2] No such file or directory: 'None/6G2EA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6ND3A failed: [Errno 2] No such file or directory: 'None/6ND3A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:47] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# [04:32:47] ERROR: Could not sanitize molecule ending on line 60
# [04:32:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 9 10 11 12 13
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6OS6A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6OS6A failed: [Errno 2] No such file or directory: 'None/6OS6A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  93%|█████████▎| 133/143 [00:12<00:00, 11.79it/s][04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6INZA failed: [Errno 2] No such file or directory: 'None/6INZA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6IBYA failed: [Errno 2] No such file or directory: 'None/6IBYA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  94%|█████████▍| 135/143 [00:12<00:00, 11.82it/s][04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:47] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 14 15 16 17 33
# [04:32:47] ERROR: Could not sanitize molecule ending on line 145
# [04:32:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 14 15 16 17 33
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6GJ7A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6GJ7A failed: [Errno 2] No such file or directory: 'None/6GJ7A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:47] Can't kekulize mol.  Unkekulized atoms: 60 61 62 63 64 65 66 67 68
# [04:32:47] ERROR: Could not sanitize molecule ending on line 466
# [04:32:47] ERROR: Can't kekulize mol.  Unkekulized atoms: 60 61 62 63 64 65 66 67 68
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6Q4QA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6Q4QA failed: [Errno 2] No such file or directory: 'None/6Q4QA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  96%|█████████▌| 137/143 [00:13<00:00,  7.96it/s][04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6HBNA failed: [Errno 2] No such file or directory: 'None/6HBNA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:47] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6TELA failed: [Errno 2] No such file or directory: 'None/6TELA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  97%|█████████▋| 139/143 [00:13<00:00,  8.34it/s][04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6P8YA failed: [Errno 2] No such file or directory: 'None/6P8YA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 18
# [04:32:48] ERROR: Could not sanitize molecule ending on line 78
# [04:32:48] ERROR: Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 18
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6PYAA/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6PYAA failed: [Errno 2] No such file or directory: 'None/6PYAA/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
#  99%|█████████▊| 141/143 [00:13<00:00,  9.25it/s][04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:48] Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 19 20 21 22 23
# [04:32:48] ERROR: Could not sanitize molecule ending on line 145
# [04:32:48] ERROR: Can't kekulize mol.  Unkekulized atoms: 5 6 7 8 19 20 21 22 23
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6GJ8A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6GJ8A failed: [Errno 2] No such file or directory: 'None/6GJ8A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
# [04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# [04:32:48] Can't kekulize mol.  Unkekulized atoms: 28 29 30 31 32
# [04:32:48] ERROR: Could not sanitize molecule ending on line 133
# [04:32:48] ERROR: Can't kekulize mol.  Unkekulized atoms: 28 29 30 31 32
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/data/pipeline.py:905: UserWarning: RDKit sanitization failed for ligand /home/jupyter/neuralplexermodels_downstream_datasets_predictions/downstream_test_datasets/pdbbind_tasks/binding_site_recovery/6MO2A/ligand.sdf: Python argument types in
#     rdkit.Chem.rdmolops.RemoveHs(NoneType)
# did not match C++ signature:
#     RemoveHs(RDKit::ROMol mol, RDKit::MolOps::RemoveHsParameters params, bool sanitize=True)
#     RemoveHs(RDKit::ROMol mol, bool implicitOnly=False, bool updateExplicitCount=False, bool sanitize=True), loading raw attributes
#   warnings.warn(
# [04:32:48] Warning: molecule is tagged as 2D, but at least one Z coordinate is not zero. Marking the mol as 3D.
# /home/jupyter/google_cloud/protein_ligand/neuralPlexer/NeuralPLexer/neuralplexer/inference.py:461: UserWarning: Sample 6MO2A failed: [Errno 2] No such file or directory: 'None/6MO2A/af2_template.pdb'
#   warnings.warn(f"Sample {sample_id} failed: {e}")
#
# 100%|██████████| 143/143 [00:13<00:00,  9.31it/s]
# 100%|██████████| 143/143 [00:13<00:00, 10.51it/s]
